# %%
import TreeSOM

# %% [markdown]
# ## Load image files

# %%
imagefiles = TreeSOM.LoadImageDirectory(img_directory='/project/rpp-chime/hgan/notebooks/TreeSOM/images', extension='jpg')

# %%
TreeSOM.ShowImages(imagefiles)

# %% [markdown]
# ## Run disccofan to create trees

# %%
TreeSOM.CreateTrees(imagefiles,
    extension='jpg',
    disccofan_directory='/project/rpp-chime/hgan/scratch/software/disccofan-master',
    base_directory='/project/rpp-chime/hgan/notebooks/TreeSOM',)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# 08-09-2023 16:35:13 0 WARN  Floating point activated, but data is 8 bits.
# 08-09-2023 16:35:14 0 WARN  Floating point activated, but data is 8 bits.
# 08-09-2023 16:35:15 0 WARN  Floating point activated, but data is 8 bits.
# 08-09-2023 16:35:16 0 WARN  Floating point activated, but data is 8 bits.
# 08-09-2023 16:35:18 0 WARN  Floating point activated, but data is 8 bits.
# 08-09-2023 16:35:19 0 WARN  Floating point activated, but data is 8 bits.
# 08-09-2023 16:35:20 0 WARN  Floating point activated, but data is 8 bits.
# 08-09-2023 16:35:21 0 WARN  Floating point activated, but data is 8 bits.
# 08-09-2023 16:35:22 0 WARN  Floating point activated, but data is 8 bits.

# %%
train_set = TreeSOM.LoadTrees(
    base_directory='/project/rpp-chime/hgan/notebooks/TreeSOM',)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# 797638 nodes are loaded in total!

# %% [markdown]
# ## Train self-organising maps

# %%
train_set = train_set
base_directory = '/project/rpp-chime/hgan/notebooks/TreeSOM'
n_neurons = 6
m_neurons = 6
s_features = [4,5,6,8,9,13,14]
max_iter = 10000

TreeSOM.TrainSOM(train_set, base_directory, n_neurons, m_neurons, s_features, max_iter,)
# Out:
# Selected training attributes are :
# [' flux' ' Volume' ' Elongation' ' Sparseness' ' Non-compactness' ' cm_wx'
#  ' cm_wy']
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.11778776106186624
# Training completed!

# %%
TreeSOM.GetWinningNeurons_in_Parallel(base_directory, n_neurons, m_neurons, s_features,)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Create pattern spectra

# %%
TreeSOM.CreateGValueFluxTables(base_directory, n_neurons, m_neurons,)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
TreeSOM.GetPatternSpectra(base_directory, n_neurons, m_neurons,)

# %%
TreeSOM.GetNormalisedExcess(base_directory, n_neurons, m_neurons,)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %% [markdown]
# ## Plot results

# %%
TreeSOM.PlotNormalisedSelfOrganisedPS(
    base_directory,
    n_neurons,
    m_neurons,
    attribute = 'flux', # flux or gval 
    tree_extension = 'csv'  
)

# %% [markdown]
# ## Filtering images using neurons
